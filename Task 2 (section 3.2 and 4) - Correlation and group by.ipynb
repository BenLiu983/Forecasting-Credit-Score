# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('classic')
# %matplotlib inline
import seaborn as sns
sns.set()
from pandas.plotting import scatter_matrix

# %% [markdown]
# # Import dataset

# %%
data = pd.read_csv("loan_final313.csv")

# %%
display(data.head())
# Out:
#         id  year     issue_d  final_d  emp_length_int home_ownership  \
# 0  1077501  2011  01/12/2011  1012015            10.0           RENT
# 1  1077430  2011  01/12/2011  1042013             0.5           RENT
# 2  1077175  2011  01/12/2011  1062014            10.0           RENT
# 3  1076863  2011  01/12/2011  1012015            10.0           RENT
# 4  1075358  2011  01/12/2011  1012016             1.0           RENT
#
#    home_ownership_cat income_category  annual_inc  income_cat    ...     \
# 0                   1             Low       24000           1    ...
# 1                   1             Low       30000           1    ...
# 2                   1             Low       12252           1    ...
# 3                   1             Low       49200           1    ...
# 4                   1             Low       80000           1    ...
#
#    loan_condition_cat interest_rate  grade grade_cat    dti   total_pymnt  \
# 0                   0         10.65      B         2  27.65   5861.071414
# 1                   1         15.27      C         3   1.00   1008.710000
# 2                   0         15.96      C         3   8.72   3003.653644
# 3                   0         13.49      C         3  20.00  12226.302210
# 4                   0         12.69      B         2  17.94   3242.170000
#
#    total_rec_prncp recoveries  installment    region
# 0          5000.00       0.00       162.87   munster
# 1           456.46     117.08        59.83  leinster
# 2          2400.00       0.00        84.33  cannught
# 3         10000.00       0.00       339.31    ulster
# 4          2233.10       0.00        67.79    ulster
#
# [5 rows x 30 columns]

# %%
data.shape
# Out:
# (887379, 30)

# %% [markdown]
# # Correlation of 9 main features

# %%
data0 = data.iloc[:,[8, 4, 21, 10, 12, 20, 6, 16, 18, 14]]
display(data0.head())
# Out:
#    annual_inc  emp_length_int  interest_rate  loan_amount  term_cat  \
# 0       24000            10.0          10.65         5000         1
# 1       30000             0.5          15.27         2500         2
# 2       12252            10.0          15.96         2400         1
# 3       49200            10.0          13.49        10000         1
# 4       80000             1.0          12.69         3000         2
#
#    loan_condition_cat  home_ownership_cat  purpose_cat  interest_payment_cat  \
# 0                   0                   1            1                     1
# 1                   1                   1            2                     2
# 2                   0                   1            3                     2
# 3                   0                   1            4                     2
# 4                   0                   1            4                     1
#
#    application_type_cat
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 4                     1

# %%
data0.shape
# Out:
# (887379, 10)

# %% [markdown]
# data cleansing： drop application type with "Joint"

# %%
data0 = data0[data0.application_type_cat != 2]

# %%
data0.shape
# Out:
# (886868, 10)

# %% [markdown]
# Since the last column are all "1", we can also drop that column.

# %%
data0 = data0.drop(columns=['application_type_cat'])

# %%
data0.shape
# Out:
# (886868, 9)

# %% [markdown]
# According to task 1, we can drop 3 owenership types with few instances

# %%
data0 = data0[data0.home_ownership_cat < 4]

# %%
data0.shape
# Out:
# (886633, 9)

# %%
cor_mat0 = np.corrcoef(data0.T)
display(cor_mat0)
# Out:
# array([[ 1.        ,  0.06338482, -0.07270855,  0.33281201,  0.05840776,
#         -0.03413852,  0.15508784,  0.00475926, -0.06308343],
#        [ 0.06338482,  1.        ,  0.00892707,  0.10384429,  0.06745918,
#         -0.01577245,  0.2046922 ,  0.01922032,  0.0076893 ],
#        [-0.07270855,  0.00892707,  1.        ,  0.14477226,  0.42799221,
#          0.17559287, -0.06448232,  0.15816046,  0.80225527],
#        [ 0.33281201,  0.10384429,  0.14477226,  1.        ,  0.41158593,
#          0.00362685,  0.19653521, -0.03704862,  0.11267175],
#        [ 0.05840776,  0.06745918,  0.42799221,  0.41158593,  1.        ,
#          0.03973816,  0.1100637 ,  0.02927544,  0.35123899],
#        [-0.03413852, -0.01577245,  0.17559287,  0.00362685,  0.03973816,
#          1.        , -0.03750192,  0.03122047,  0.14062885],
#        [ 0.15508784,  0.2046922 , -0.06448232,  0.19653521,  0.1100637 ,
#         -0.03750192,  1.        ,  0.02272858, -0.05036433],
#        [ 0.00475926,  0.01922032,  0.15816046, -0.03704862,  0.02927544,
#          0.03122047,  0.02272858,  1.        ,  0.13535799],
#        [-0.06308343,  0.0076893 ,  0.80225527,  0.11267175,  0.35123899,
#          0.14062885, -0.05036433,  0.13535799,  1.        ]])

# %%
fig0, ax0 = plt.subplots()
sns.heatmap(data0.corr(method='pearson'), annot=True, fmt='.4f', 
            cmap=plt.get_cmap('coolwarm'), cbar=False, ax=ax0)
ax0.set_yticklabels(ax0.get_yticklabels(), rotation="horizontal")
plt.savefig('cor_heat.png', bbox_inches='tight', pad_inches=0.0)

# %%
import time
start_time = time.perf_counter()
g1 = sns.pairplot(data0, diag_kind='kde')
end_time = time.perf_counter()
print (end_time - start_time, "seconds")
g1.savefig('nine_fea_cor.png')
# Out:
# C:\Users\liuzh\Anaconda3\envs\py37\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# 547.4302756 seconds

# %%
display(data0.head())
# Out:
#    annual_inc  emp_length_int  interest_rate  loan_amount  term_cat  \
# 0       24000            10.0          10.65         5000         1
# 1       30000             0.5          15.27         2500         2
# 2       12252            10.0          15.96         2400         1
# 3       49200            10.0          13.49        10000         1
# 4       80000             1.0          12.69         3000         2
#
#    loan_condition_cat  home_ownership_cat  purpose_cat  interest_payment_cat
# 0                   0                   1            1                     1
# 1                   1                   1            2                     2
# 2                   0                   1            3                     2
# 3                   0                   1            4                     2
# 4                   0                   1            4                     1

# %% [markdown]
# # Correlation 2 - Numeric features and loan condition (good / bad)

# %% [markdown]
# 2.1 Outline

# %%
data2 = data0.iloc[:,0:6]
display(data2.head())
# Out:
#    annual_inc  emp_length_int  interest_rate  loan_amount  term_cat  \
# 0       24000            10.0          10.65         5000         1
# 1       30000             0.5          15.27         2500         2
# 2       12252            10.0          15.96         2400         1
# 3       49200            10.0          13.49        10000         1
# 4       80000             1.0          12.69         3000         2
#
#    loan_condition_cat
# 0                   0
# 1                   1
# 2                   0
# 3                   0
# 4                   0

# %% [markdown]
# 2.4 Group by

# %%
data2.groupby('loan_condition_cat')['annual_inc'].describe()
# Out:
#                        count          mean           std     min      25%  \
# loan_condition_cat
# 0                   819255.0  75672.925048  64663.456426  1896.0  46000.0
# 1                    67378.0  67335.778014  64831.528628  2000.0  42000.0
#
#                         50%      75%        max
# loan_condition_cat
# 0                   65000.0  90000.0  9500000.0
# 1                   58000.0  80000.0  8900060.0

# %% [markdown]
# * The average annual income of clients who belonged to "Good Loan" category is higher than those belonged to "Bad Loan" by nearly 10,000, which accords with common sense.

# %%
data2.groupby('loan_condition_cat')['interest_rate'].describe()
# Out:
#                        count       mean       std   min    25%    50%    75%  \
# loan_condition_cat
# 0                   819255.0  13.024858  4.313779  5.32   9.76  12.69  15.61
# 1                    67378.0  15.928478  4.313723  5.32  12.99  15.61  18.75
#
#                       max
# loan_condition_cat
# 0                   28.99
# 1                   28.99

# %% [markdown]
# * The interest rate of "Good Loan" category is averaging about 3% larger than that of "Bad Loan". This is reasonable because the higher the interest rate, the more likely the clients fail to pay the loan.

# %%
data2.groupby('loan_condition_cat')['emp_length_int'].describe()
# Out:
#                        count      mean       std  min  25%   50%   75%   max
# loan_condition_cat
# 0                   819255.0  6.066695  3.510008  0.5  3.0  6.05  10.0  10.0
# 1                    67378.0  5.857934  3.468708  0.5  3.0  6.00  10.0  10.0

# %%
data2.groupby('loan_condition_cat')['loan_amount'].describe()
# Out:
#                        count          mean          std    min     25%  \
# loan_condition_cat
# 0                   819255.0  14744.680228  8431.389894  500.0  8000.0
# 1                    67378.0  14860.122369  8471.809481  500.0  8325.0
#
#                         50%      75%      max
# loan_condition_cat
# 0                   13000.0  20000.0  35000.0
# 1                   13175.0  20000.0  35000.0

# %% [markdown]
# # Correlation 3 -  Numeric variables and home ownership

# %% [markdown]
# 3.1 Outline

# %%
data3 = data0.iloc[:,[0, 1, 2, 3, 5, 6]]
display(data3.head())
# Out:
#    annual_inc  emp_length_int  interest_rate  loan_amount  loan_condition_cat  \
# 0       24000            10.0          10.65         5000                   0
# 1       30000             0.5          15.27         2500                   1
# 2       12252            10.0          15.96         2400                   0
# 3       49200            10.0          13.49        10000                   0
# 4       80000             1.0          12.69         3000                   0
#
#    home_ownership_cat
# 0                   1
# 1                   1
# 2                   1
# 3                   1
# 4                   1

# %% [markdown]
# 3.3 Group by

# %%
display(data3.head())
# Out:
#    annual_inc  emp_length_int  interest_rate  loan_amount  loan_condition_cat  \
# 0       24000            10.0          10.65         5000                   0
# 1       30000             0.5          15.27         2500                   1
# 2       12252            10.0          15.96         2400                   0
# 3       49200            10.0          13.49        10000                   0
# 4       80000             1.0          12.69         3000                   0
#
#    home_ownership_cat
# 0                   1
# 1                   1
# 2                   1
# 3                   1
# 4                   1

# %%
data3.groupby('home_ownership_cat')['annual_inc'].describe()
# Out:
#                        count          mean           std     min      25%  \
# home_ownership_cat
# 1                   355995.0  63988.792107  51158.571867  1896.0  40000.0
# 2                    87435.0  68920.004815  62494.067061  4000.0  40000.0
# 3                   443203.0  85122.757730  72788.054401  3800.0  54000.0
#
#                         50%       75%        max
# home_ownership_cat
# 1                   55000.0   76000.0  8900060.0
# 2                   56000.0   82000.0  8253000.0
# 3                   73000.0  100000.0  9500000.0

# %% [markdown]
# * It is generally believed that clients who own a house have higher income than those who bought a house with a mortgage. However, in this case, an interesting finding is that the average income of clients who bought a house with a mortgage have higher annual income than those who own a house, by a relevantly large margin.

# %%
table1 = data3.groupby('home_ownership_cat')['annual_inc'].mean().reset_index()
display(table1)
# Out:
#    home_ownership_cat    annual_inc
# 0                   1  63988.792107
# 1                   2  68920.004815
# 2                   3  85122.757730

# %%
table2 = table1.rename(index={0: "Rent", 1: "Own", 2: "Mortgage"})
display(table2)
# Out:
#           home_ownership_cat    annual_inc
# Rent                       1  63988.792107
# Own                        2  68920.004815
# Mortgage                   3  85122.757730

# %%
table3 = table2.rename(columns={"annual_inc": "Average annual income"})
display(table3)
table3.iloc[:,0]
# Out:
#           home_ownership_cat  Average annual income
# Rent                       1           63988.792107
# Own                        2           68920.004815
# Mortgage                   3           85122.757730
# Rent        1
# Own         2
# Mortgage    3
# Name: home_ownership_cat, dtype: int64

# %%
with sns.axes_style('white'):
    g2 = sns.barplot(x="Average annual income", y=table3.index, data=table3, palette="Blues_d")
    g2.set(xlim=(0, 100000),xlabel="Average annual income", ylabel="Home ownership")
    g2.figure.savefig('inc_hom_rel.png')

# %%
data3.groupby('home_ownership_cat')['interest_rate'].describe()
# Out:
#                        count       mean       std   min    25%    50%    75%  \
# home_ownership_cat
# 1                   355995.0  13.575296  4.292134  5.32  10.64  13.33  16.49
# 2                    87435.0  13.265701  4.430533  5.32   9.99  12.99  16.29
# 3                   443203.0  12.976639  4.425095  5.32   9.25  12.69  15.61
#
#                       max
# home_ownership_cat
# 1                   28.99
# 2                   28.99
# 3                   28.99

# %% [markdown]
# * Among all home_ownership category, the interest rate of "Mortgage" is the lowest. One of the possible reason is that some of the clients apply mortgage from this bank, and generally the interest rate of house mortgage is relevantly low because of the long term.

# %%
data3.groupby('home_ownership_cat')['loan_amount'].describe()
# Out:
#                        count          mean          std    min      25%  \
# home_ownership_cat
# 1                   355995.0  12869.430750  7627.774073  500.0   7000.0
# 2                    87435.0  14221.752731  8337.604353  700.0   8000.0
# 3                   443203.0  16371.654468  8737.565594  500.0  10000.0
#
#                         50%      75%      max
# home_ownership_cat
# 1                   11200.0  17000.0  35000.0
# 2                   12000.0  20000.0  35000.0
# 3                   15000.0  22000.0  35000.0

# %% [markdown]
# * Except the outliner category "ANY" with only 3 instances, the loan amount of "Mortgage" and "Own" are the higher than others. It makes sense since these clients have house property as collateral, which ease the bank's concern.

# %%
data3.groupby('home_ownership_cat')['emp_length_int'].describe()
# Out:
#                        count      mean       std  min  25%   50%   75%   max
# home_ownership_cat
# 1                   355995.0  5.179287  3.484572  0.5  2.0  5.00   9.0  10.0
# 2                    87435.0  6.273288  3.407814  0.5  3.0  6.05  10.0  10.0
# 3                   443203.0  6.706997  3.393290  0.5  4.0  7.00  10.0  10.0

# %% [markdown]
# # Correlation 4 - Numeric variables and loan term

# %% [markdown]
# 4.1 Outline

# %%
data4 = data0.iloc[:,[0, 1, 2, 3, 4]]
display(data4.head())
# Out:
#    annual_inc  emp_length_int  interest_rate  loan_amount  term_cat
# 0       24000            10.0          10.65         5000         1
# 1       30000             0.5          15.27         2500         2
# 2       12252            10.0          15.96         2400         1
# 3       49200            10.0          13.49        10000         1
# 4       80000             1.0          12.69         3000         2

# %% [markdown]
# 4.4 Group By

# %%
data4.groupby('term_cat')['annual_inc'].describe()
# Out:
#              count          mean           std     min      25%      50%  \
# term_cat
# 1         620666.0  72565.055611  66307.202295  1896.0  43000.0  60000.0
# 2         265967.0  80813.444732  60441.136639  4800.0  52000.0  70000.0
#
#               75%        max
# term_cat
# 1         87000.0  9000000.0
# 2         95000.0  9500000.0

# %%
data4.groupby('term_cat')['interest_rate'].describe()
# Out:
#              count       mean       std   min    25%    50%    75%    max
# term_cat
# 1         620666.0  12.017853  3.853257  5.32   8.90  11.99  14.47  28.99
# 2         265967.0  16.110408  4.199324  5.79  13.18  15.61  18.79  28.99

# %% [markdown]
# * In this case, the average interest rate of long term loan is larger than that of short term loan, which accord with common sense.

# %%
data4.groupby('term_cat')['loan_amount'].describe()
# Out:
#              count          mean          std     min      25%      50%  \
# term_cat
# 1         620666.0  12480.944622  7780.613778   500.0   6625.0  10000.0
# 2         265967.0  20056.624882  7463.906145  1000.0  14400.0  19425.0
#
#               75%      max
# term_cat
# 1         16000.0  35000.0
# 2         25000.0  35000.0

# %% [markdown]
# * An intereting finding is that the percentage of loan term and relevant loan amount is very close in this case

# %%
data.groupby('term_cat')['emp_length_int'].describe()
# Out:
#              count      mean       std  min  25%   50%   75%   max
# term_cat
# 1         621125.0  5.895494  3.496052  0.5  3.0  6.05  10.0  10.0
# 2         266254.0  6.412317  3.507199  0.5  3.0  7.00  10.0  10.0

# %% [markdown]
# # Correlation 5 - Numeric variables and interest payment

# %% [markdown]
# 5.1 Outline

# %%
data5 = data0.iloc[:,[0, 1, 2, 3, 8]]
display(data5.head())
# Out:
#    annual_inc  emp_length_int  interest_rate  loan_amount  \
# 0       24000            10.0          10.65         5000
# 1       30000             0.5          15.27         2500
# 2       12252            10.0          15.96         2400
# 3       49200            10.0          13.49        10000
# 4       80000             1.0          12.69         3000
#
#    interest_payment_cat
# 0                     1
# 1                     2
# 2                     2
# 3                     2
# 4                     1

# %% [markdown]
# 5.4 Group by

# %%
data5.groupby('interest_payment_cat')['annual_inc'].describe()
# Out:
#                          count          mean           std     min      25%  \
# interest_payment_cat
# 1                     465007.0  78926.647653  72456.187561  2000.0  48000.0
# 2                     421626.0  70752.108779  54603.842859  1896.0  44000.0
#
#                           50%      75%        max
# interest_payment_cat
# 1                     67000.0  95000.0  9500000.0
# 2                     60000.0  85000.0  8900060.0

# %%
data5.groupby('interest_payment_cat')['interest_rate'].describe()
# Out:
#                          count       mean       std    min    25%    50%  \
# interest_payment_cat
# 1                     465007.0   9.898140  2.235274   5.32   7.90   9.99
# 2                     421626.0  16.937297  2.979805  13.24  14.49  16.29
#
#                         75%    max
# interest_payment_cat
# 1                     11.99  13.23
# 2                     18.54  28.99

# %%
data5.groupby('interest_payment_cat')['emp_length_int'].describe()
# Out:
#                          count      mean       std  min  25%   50%   75%   max
# interest_payment_cat
# 1                     465007.0  6.025151  3.520002  0.5  3.0  6.05  10.0  10.0
# 2                     421626.0  6.079153  3.493067  0.5  3.0  6.05  10.0  10.0

# %%
data5.groupby('interest_payment_cat')['loan_amount'].describe()
# Out:
#                          count          mean          std    min     25%  \
# interest_payment_cat
# 1                     465007.0  13848.535398  7832.087930  500.0  8000.0
# 2                     421626.0  15751.477435  8947.059452  600.0  9000.0
#
#                           50%      75%      max
# interest_payment_cat
# 1                     12000.0  19200.0  35000.0
# 2                     14400.0  21000.0  35000.0

# %% [markdown]
# # Correlation 6 - Numeric variables and purpose

# %% [markdown]
# 6.1 Outline

# %%
data6 = data0.iloc[:,[0, 1, 2, 3, 7]]
display(data6.head())
# Out:
#    annual_inc  emp_length_int  interest_rate  loan_amount  purpose_cat
# 0       24000            10.0          10.65         5000            1
# 1       30000             0.5          15.27         2500            2
# 2       12252            10.0          15.96         2400            3
# 3       49200            10.0          13.49        10000            4
# 4       80000             1.0          12.69         3000            4

# %% [markdown]
# 6.3 Group by

# %%
data6.groupby('purpose_cat')['annual_inc'].describe()
# Out:
#                 count          mean            std     min      25%      50%  \
# purpose_cat
# 1            205996.0  75111.453402   64196.383435  4000.0  45000.0  65000.0
# 2              8859.0  67888.729766  100985.396871  3000.0  40000.0  56000.0
# 3             10361.0  89876.542515   73151.524322  6695.0  50000.0  72500.0
# 4             42839.0  69793.425990   58835.689526  2000.0  40000.0  58000.0
# 5              2346.0  69469.114237   47152.931253  7200.0  43000.0  60000.0
# 6            523803.0  73902.536196   61111.853613  1896.0  45600.0  64000.0
# 7             51788.0  90294.215687   88881.276644  7000.0  52000.0  75000.0
# 8             17267.0  76701.487346   61982.558129  5000.0  45000.0  64800.0
# 9              8533.0  72150.625337   94233.727065  7500.0  42240.0  60000.0
# 10             5410.0  68180.563586   55072.875729  3600.0  39500.0  55000.0
# 11             4735.0  66884.224921   41260.536464  4888.0  40000.0  58000.0
# 12             3704.0  80474.191685   56193.610283  7000.0  47575.0  66000.0
# 13              574.0  74171.595819   70493.122229  8400.0  41000.0  60000.0
# 14              418.0  51252.729665   41462.277784  3300.0  24249.0  40000.0
#
#                   75%        max
# purpose_cat
# 1             90000.0  9500000.0
# 2             80000.0  7000000.0
# 3            105000.0  1500000.0
# 4             82500.0  3964280.0
# 5             81629.0   900000.0
# 6             90000.0  9000000.0
# 7            105000.0  7600000.0
# 8             92500.0  3000000.0
# 9             85000.0  7500000.0
# 10            80000.0  1200000.0
# 11            80000.0   600000.0
# 12            96550.0   780000.0
# 13            85000.0   985000.0
# 14            65000.0   425000.0

# %% [markdown]
# * Among all purposes, clients with loan purpose "home improvement" and "small business" have higher income than others. This makes senses, because people who own a small business or require home development is more likely to be wealthy.
# * On the contrary, customers who applied for a loan due to education have the lowest average income, which is also reasonable since educational cost are basic expenditure for a family.

# %%
data6.groupby('purpose_cat')['emp_length_int'].describe()
# Out:
#                 count      mean       std  min  25%   50%   75%   max
# purpose_cat
# 1            205996.0  5.919980  3.524259  0.5  3.0  6.05  10.0  10.0
# 2              8859.0  5.383949  3.502356  0.5  2.0  5.00  10.0  10.0
# 3             10361.0  5.508629  3.471294  0.5  2.0  5.00  10.0  10.0
# 4             42839.0  5.939533  3.505388  0.5  3.0  6.05  10.0  10.0
# 5              2346.0  4.487681  3.204027  0.5  2.0  4.00   7.0  10.0
# 6            523803.0  6.132474  3.506022  0.5  3.0  6.05  10.0  10.0
# 7             51788.0  6.520028  3.371878  0.5  3.0  7.00  10.0  10.0
# 8             17267.0  5.553232  3.466907  0.5  2.0  5.00  10.0  10.0
# 9              8533.0  5.956856  3.468136  0.5  3.0  6.05  10.0  10.0
# 10             5410.0  4.497449  3.473844  0.5  1.0  4.00   7.0  10.0
# 11             4735.0  6.276727  3.336769  0.5  3.0  6.05  10.0  10.0
# 12             3704.0  5.403847  3.453355  0.5  2.0  5.00  10.0  10.0
# 13              574.0  6.090679  3.441003  0.5  3.0  6.05  10.0  10.0
# 14              418.0  3.547727  3.175170  0.5  1.0  2.00   5.0  10.0

# %% [markdown]
# * On average, clients with loan purpose "home improvement" have longer employment length than others.

# %%
data6.groupby('purpose_cat')['loan_amount'].describe()
# Out:
#                 count          mean          std     min     25%      50%  \
# purpose_cat
# 1            205996.0  15337.735199  8287.612744   500.0  9000.0  14000.0
# 2              8859.0   8880.454905  6171.461271  1000.0  4800.0   7000.0
# 3             10361.0  15420.162147  9284.425995   500.0  8000.0  13750.0
# 4             42839.0   9887.750648  7509.729439   500.0  4450.0   8000.0
# 5              2346.0  10470.961211  6751.358739  1000.0  5500.0   9000.0
# 6            523803.0  15425.800730  8281.261115   700.0  9325.0  14150.0
# 7             51788.0  14319.957326  8919.426715   900.0  7000.0  12000.0
# 8             17267.0  11603.959866  8608.830152  1000.0  5000.0   9575.0
# 9              8533.0   9018.492910  6844.844078   850.0  4000.0   7000.0
# 10             5410.0   7892.795749  6340.322625   800.0  3500.0   6000.0
# 11             4735.0   6289.809926  5206.578124   500.0  2825.0   5000.0
# 12             3704.0  14806.067765  8886.743340  1000.0  8000.0  12600.0
# 13              574.0   9922.081882  7566.762997  1000.0  4000.0   8000.0
# 14              418.0   6644.736842  5114.300183   500.0  3000.0   5000.0
#
#                  75%      max
# purpose_cat
# 1            20000.0  35000.0
# 2            11500.0  35000.0
# 3            21000.0  35000.0
# 4            13500.0  35000.0
# 5            14000.0  35000.0
# 6            20000.0  35000.0
# 7            20000.0  35000.0
# 8            16000.0  35000.0
# 9            12000.0  35000.0
# 10           10000.0  35000.0
# 11            8000.0  35000.0
# 12           20000.0  35000.0
# 13           14400.0  35000.0
# 14            8725.0  25000.0

# %% [markdown]
# * The loan amount of debt consolidation is averaging the highest among all the categories.

# %%
data6.groupby('purpose_cat')['interest_rate'].describe()
# Out:
#                 count       mean       std   min     25%    50%     75%    max
# purpose_cat
# 1            205996.0  11.771755  3.936872  5.32   8.380  11.53  14.160  28.99
# 2              8859.0  12.004765  4.236004  5.32   8.180  11.71  14.650  28.99
# 3             10361.0  16.236013  4.805185  5.32  12.990  16.29  19.200  28.99
# 4             42839.0  15.023260  4.525720  5.32  11.990  14.64  18.240  28.99
# 5              2346.0  14.152754  4.782861  5.42  10.380  13.99  17.930  25.99
# 6            523803.0  13.599965  4.319546  5.32  10.640  13.33  16.550  28.99
# 7             51788.0  13.026353  4.521904  5.32   9.170  12.69  15.800  28.99
# 8             17267.0  12.674613  4.498088  5.32   8.900  12.49  15.610  28.99
# 9              8533.0  14.563035  4.454620  5.32  11.530  14.09  17.570  28.99
# 10             5410.0  15.727832  4.387875  5.32  12.690  15.61  18.540  28.99
# 11             4735.0  14.340828  4.166555  5.32  11.530  13.99  17.140  27.88
# 12             3704.0  16.010270  5.172117  5.42  12.335  15.80  19.205  28.99
# 13              574.0  15.393502  4.646335  5.42  12.290  15.31  18.490  27.88
# 14              418.0  12.105526  2.693459  6.00  10.250  12.21  13.780  21.27

# %% [markdown]
# * On average, the interest rate for credit card loan is smallest, while that for small business is the largest. Since the risk of commericial loan is higher than that of personal loan.
